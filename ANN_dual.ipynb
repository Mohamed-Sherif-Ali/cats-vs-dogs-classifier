# %%
# STEP 1: Import Libraries
import tensorflow as tf
import tensorflow_datasets as tfds
from tensorflow.keras.applications import VGG16, ResNet50
from tensorflow.keras.layers import Input, GlobalAveragePooling2D, Dense, Dropout, Concatenate
from tensorflow.keras.models import Model
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# STEP 2: Load the Dataset
(train_ds, val_ds), ds_info = tfds.load(
    'cats_vs_dogs',
    split=['train[:80%]', 'train[80%:]'],
    shuffle_files=True,
    as_supervised=True,
    with_info=True
)

# STEP 3: Preprocessing & Augmentation
def preprocess(image, label):
    image = tf.image.resize(image, (224, 224))
    image = tf.cast(image, tf.float32) / 255.0
    return image, label

def augment(image, label):
    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_brightness(image, 0.1)
    return image, label

# STEP 4: Prepare the Batched Datasets
BATCH_SIZE = 32

train_batches = (train_ds
                 .map(preprocess)
                 .map(augment)
                 .shuffle(1000)
                 .batch(BATCH_SIZE)
                 .prefetch(tf.data.AUTOTUNE))

val_batches = (val_ds
               .map(preprocess)
               .batch(BATCH_SIZE)
               .prefetch(tf.data.AUTOTUNE))

# STEP 5: Build the Dual-Branch Model (VGG16 + ResNet50)
input_tensor = Input(shape=(224, 224, 3))

# VGG16
vgg = VGG16(weights='imagenet', include_top=False, input_tensor=input_tensor)
vgg.trainable = False
vgg_features = GlobalAveragePooling2D()(vgg.output)

# ResNet50
resnet = ResNet50(weights='imagenet', include_top=False, input_tensor=input_tensor)
resnet.trainable = False
resnet_features = GlobalAveragePooling2D()(resnet.output)

# Merge both
combined_features = Concatenate()([vgg_features, resnet_features])

# Classifier Head
x = Dense(256, activation='relu')(combined_features)
x = Dropout(0.5)(x)
output = Dense(1, activation='sigmoid')(x)

# Final Model
dual_model = Model(inputs=input_tensor, outputs=output)

# STEP 6: Compile the Model
dual_model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

dual_model.summary()

# STEP 7: Train the Model
EPOCHS = 10
history_dual = dual_model.fit(
    train_batches,
    validation_data=val_batches,
    epochs=EPOCHS
)

# STEP 8: Evaluate the Model
y_true = []
y_pred = []

for images, labels in val_batches:
    preds = dual_model.predict(images)
    y_true.extend(labels.numpy())
    y_pred.extend((preds > 0.5).astype("int32").flatten())

y_true = np.array(y_true)
y_pred = np.array(y_pred)

# Confusion Matrix
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=["Cat", "Dog"], yticklabels=["Cat", "Dog"])
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Dual-Branch Confusion Matrix")
plt.show()

# Classification Report
print("📋 Classification Report:")
print(classification_report(y_true, y_pred, target_names=["Cat", "Dog"]))

print("✅ Sklearn Accuracy:", accuracy_score(y_true, y_pred))

# STEP 9: Save the Model
dual_model.save("dual_branch_cats_dogs_model.keras")
# Out:
# ...
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_4       │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_pad           │ (None, 230, 230,  │          0 │ input_layer_4[0]… │
# │ (ZeroPadding2D)     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_conv (Conv2D) │ (None, 112, 112,  │      9,472 │ conv1_pad[0][0]   │
# │                     │ 64)               │            │                   │
# ...

# %%
#  Unfreeze last 4 layers of VGG16
vgg.trainable = True
for layer in vgg.layers[:-4]:
    layer.trainable = False

#  Unfreeze last 4 layers of ResNet50
resnet.trainable = True
for layer in resnet.layers[:-4]:
    layer.trainable = False

#  Re-compile the model with a smaller learning rate
dual_model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5),
    loss='binary_crossentropy',
    metrics=['accuracy']
)

#  Fine-tune for 3 epochs
dual_model.fit(
    train_batches,
    validation_data=val_batches,
    epochs=3
)

#  Save final model
dual_model.save("dual_model_finetuned_3epochs.keras")
# Out:
# Epoch 1/3
# 582/582 ━━━━━━━━━━━━━━━━━━━━ 221s 352ms/step - accuracy: 0.9812 - loss: 0.0492 - val_accuracy: 0.9675 - val_loss: 0.1002
# Epoch 2/3
# 582/582 ━━━━━━━━━━━━━━━━━━━━ 196s 334ms/step - accuracy: 0.9880 - loss: 0.0336 - val_accuracy: 0.9680 - val_loss: 0.1045
# Epoch 3/3
# 582/582 ━━━━━━━━━━━━━━━━━━━━ 196s 334ms/step - accuracy: 0.9920 - loss: 0.0245 - val_accuracy: 0.9684 - val_loss: 0.1084

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from sklearn.metrics import confusion_matrix, classification_report
import random

# ---------- 1. Accuracy & Loss Curves ----------
acc = history_finetuned.history['accuracy']
val_acc = history_finetuned.history['val_accuracy']
loss = history_finetuned.history['loss']
val_loss = history_finetuned.history['val_loss']
epochs_range = range(1, len(acc) + 1)

plt.figure(figsize=(12, 5))

# Accuracy plot
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Train Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.title('Fine-Tuning Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Loss plot
plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Train Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.title('Fine-Tuning Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.savefig("accuracy_loss_curves.png")
plt.show()


# ---------- 2. Confusion Matrix ----------
y_true = []
y_pred = []

for images, labels in val_batches:
    preds = dual_model.predict(images)
    y_true.extend(labels.numpy())
    y_pred.extend((preds > 0.5).astype("int32").flatten())

y_true = np.array(y_true)
y_pred = np.array(y_pred)

cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=["Cat", "Dog"], yticklabels=["Cat", "Dog"])
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.tight_layout()
plt.savefig("confusion_matrix.png")
plt.show()


# ---------- 3. Classification Report ----------
print("📋 Classification Report:")
print(classification_report(y_true, y_pred, target_names=["Cat", "Dog"]))


# ---------- 4. Correct vs Incorrect Predictions Grid ----------
val_images = []
val_labels = []
for images, labels in val_batches.take(5):
    val_images.extend(images)
    val_labels.extend(labels)

val_images = tf.stack(val_images)
val_labels = tf.stack(val_labels)

preds = dual_model.predict(val_images)
pred_classes = (preds > 0.5).astype("int32").flatten()

plt.figure(figsize=(15, 10))
for i in range(15):
    idx = random.randint(0, len(val_images)-1)
    plt.subplot(3, 5, i+1)
    plt.imshow(val_images[idx].numpy())
    true = "Dog" if val_labels[idx].numpy() == 1 else "Cat"
    pred = "Dog" if pred_classes[idx] == 1 else "Cat"
    color = "green" if true == pred else "red"
    plt.title(f"True: {true}\nPred: {pred}", color=color)
    plt.axis('off')

plt.suptitle("Correct vs Wrong Predictions", fontsize=16)
plt.tight_layout()
plt.savefig("prediction_grid.png")
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step
# ...
